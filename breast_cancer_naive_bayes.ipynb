# %%
import pandas as pd
# get Breast_Cancer_Dataset from UCI
breast_cancer_dataset=pd.read_csv('Breast_Cancer_Dataset.csv')
breast_cancer_dataset.head()
# Out:
#                   Class    age menopause tumor-size inv-nodes node-caps  \
# 0  no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4  no-recurrence-events  40-49   premeno        0-4       0-2        no
#
#    deg-malig breast breast-quad irradiat
# 0          3   left    left_low       no
# 1          2  right    right_up       no
# 2          2   left    left_low       no
# 3          2  right     left_up       no
# 4          2  right   right_low       no

# %%
breast_cancer_dataset.shape
# Out:
# (286, 10)

# %%
breast_cancer_dataset.dtypes
# Out:
# Class          object
# age            object
# menopause      object
# tumor-size     object
# inv-nodes      object
# node-caps      object
# deg-malig       int64
# breast         object
# breast-quad    object
# irradiat       object
# dtype: object

# %%
breast_cancer_dict={}
for col in breast_cancer_dataset:
    breast_cancer_dict.update({col:breast_cancer_dataset[col].unique().tolist()})

# breast_cancer_dataset.astype('object').describe(include='all').loc['unique', :]
print(breast_cancer_dict)
# Out:
# {'Class': ['no-recurrence-events', 'recurrence-events'], 'age': ['30-39', '40-49', '60-69', '50-59', '70-79', '20-29'], 'menopause': ['premeno', 'ge40', 'lt40'], 'tumor-size': ['30-34', '20-24', '15-19', '0-4', '25-29', '50-54', '10-14', '40-44', '35-39', '5-9', '45-49'], 'inv-nodes': ['0-2', '6-8', '9-11', '3-5', '15-17', '12-14', '24-26'], 'node-caps': ['no', 'yes', '?'], 'deg-malig': [3, 2, 1], 'breast': ['left', 'right'], 'breast-quad': ['left_low', 'right_up', 'left_up', 'right_low', 'central', '?'], 'irradiat': ['no', 'yes']}

# %%
breast_cancer_dataset=breast_cancer_dataset.drop(breast_cancer_dataset.loc[breast_cancer_dataset['node-caps'] == '?'].index)
breast_cancer_dataset=breast_cancer_dataset.drop(breast_cancer_dataset.loc[breast_cancer_dataset['breast-quad'] == '?'].index)
breast_cancer_dataset.shape
# Out:
# (277, 10)

# %%
breast_cancer_dataset_modified=breast_cancer_dataset.reset_index(drop=True)
breast_cancer_dataset_modified
# Out:
#                     Class    age menopause tumor-size inv-nodes node-caps  \
# 0    no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3    no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4    no-recurrence-events  40-49   premeno        0-4       0-2        no
# ..                    ...    ...       ...        ...       ...       ...
# 272     recurrence-events  30-39   premeno      30-34       0-2        no
# 273     recurrence-events  30-39   premeno      20-24       0-2        no
# 274     recurrence-events  60-69      ge40      20-24       0-2        no
# 275     recurrence-events  40-49      ge40      30-34       3-5        no
# 276     recurrence-events  50-59      ge40      30-34       3-5        no
#
#      deg-malig breast breast-quad irradiat
# 0            3   left    left_low       no
# 1            2  right    right_up       no
# 2            2   left    left_low       no
# 3            2  right     left_up       no
# 4            2  right   right_low       no
# ..         ...    ...         ...      ...
# 272          2   left     left_up       no
# 273          3   left     left_up      yes
# 274          1  right     left_up       no
# 275          3   left    left_low       no
# 276          3   left    left_low       no
#
# [277 rows x 10 columns]

# %%
features = breast_cancer_dataset_modified.columns.tolist()
features.remove('Class')
features.remove('irradiat')
print(features)
# Out:
# ['age', 'menopause', 'tumor-size', 'inv-nodes', 'node-caps', 'deg-malig', 'breast', 'breast-quad']

# %%
print('=' * 30)
for var in features:
    print(breast_cancer_dataset_modified[var].value_counts().sort_values(ascending=False) / breast_cancer_dataset_modified.shape[0])
    print('=' * 30)
    print()
# Out:
# ==============================
# 50-59    0.328520
# 40-49    0.321300
# 60-69    0.198556
# 30-39    0.129964
# 70-79    0.018051
# 20-29    0.003610
# Name: age, dtype: float64
# ==============================
#
# premeno    0.537906
# ge40       0.444043
# lt40       0.018051
# Name: menopause, dtype: float64
# ==============================
#
# 30-34    0.205776
# 25-29    0.184116
# 20-24    0.173285
# 15-19    0.104693
# 10-14    0.101083
# 40-44    0.079422
# 35-39    0.068592
# 0-4      0.028881
# 50-54    0.028881
# 5-9      0.014440
# 45-49    0.010830
# Name: tumor-size, dtype: float64
# ==============================
#
# 0-2      0.754513
# 3-5      0.122744
# 6-8      0.061372
# 9-11     0.025271
# 15-17    0.021661
# 12-14    0.010830
# 24-26    0.003610
# Name: inv-nodes, dtype: float64
# ==============================
#
# no     0.797834
# yes    0.202166
# Name: node-caps, dtype: float64
# ==============================
#
# 2    0.465704
# 3    0.296029
# 1    0.238267
# Name: deg-malig, dtype: float64
# ==============================
#
# left     0.523466
# right    0.476534
# Name: breast, dtype: float64
# ==============================
#
# left_low     0.382671
# left_up      0.339350
# right_up     0.119134
# right_low    0.083032
# central      0.075812
# Name: breast-quad, dtype: float64
# ==============================

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()
data_encoded = encoder.fit_transform(breast_cancer_dataset_modified[features])
breast_cancer_dataset_encoded = pd.DataFrame(data_encoded, columns=features)
breast_cancer_dataset_encoded
# Out:
#      age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0    1.0        2.0         5.0        0.0        0.0        2.0     0.0
# 1    2.0        2.0         3.0        0.0        0.0        1.0     1.0
# 2    2.0        2.0         3.0        0.0        0.0        1.0     0.0
# 3    4.0        0.0         2.0        0.0        0.0        1.0     1.0
# 4    2.0        2.0         0.0        0.0        0.0        1.0     1.0
# ..   ...        ...         ...        ...        ...        ...     ...
# 272  1.0        2.0         5.0        0.0        0.0        1.0     0.0
# 273  1.0        2.0         3.0        0.0        0.0        2.0     0.0
# 274  4.0        0.0         3.0        0.0        0.0        0.0     1.0
# 275  2.0        0.0         5.0        4.0        0.0        2.0     0.0
# 276  3.0        0.0         5.0        4.0        0.0        2.0     0.0
#
#      breast-quad
# 0            1.0
# 1            4.0
# 2            1.0
# 3            2.0
# 4            3.0
# ..           ...
# 272          2.0
# 273          2.0
# 274          2.0
# 275          1.0
# 276          1.0
#
# [277 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
target_encoded = encoder.fit_transform(breast_cancer_dataset_modified['irradiat'])
breast_cancer_dataset_encoded['irradiat'] = target_encoded
breast_cancer_dataset_encoded
# Out:
#      age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0    1.0        2.0         5.0        0.0        0.0        2.0     0.0
# 1    2.0        2.0         3.0        0.0        0.0        1.0     1.0
# 2    2.0        2.0         3.0        0.0        0.0        1.0     0.0
# 3    4.0        0.0         2.0        0.0        0.0        1.0     1.0
# 4    2.0        2.0         0.0        0.0        0.0        1.0     1.0
# ..   ...        ...         ...        ...        ...        ...     ...
# 272  1.0        2.0         5.0        0.0        0.0        1.0     0.0
# 273  1.0        2.0         3.0        0.0        0.0        2.0     0.0
# 274  4.0        0.0         3.0        0.0        0.0        0.0     1.0
# 275  2.0        0.0         5.0        4.0        0.0        2.0     0.0
# 276  3.0        0.0         5.0        4.0        0.0        2.0     0.0
#
#      breast-quad  irradiat
# 0            1.0         0
# 1            4.0         0
# 2            1.0         0
# 3            2.0         0
# 4            3.0         0
# ..           ...       ...
# 272          2.0         0
# 273          2.0         1
# 274          2.0         0
# 275          1.0         0
# 276          1.0         0
#
# [277 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(breast_cancer_dataset_encoded.drop('irradiat', axis=1), breast_cancer_dataset_encoded['irradiat'], test_size=0.3, random_state=143)

# %%
from sklearn.naive_bayes import CategoricalNB
gategorical_nb_model = CategoricalNB()
gategorical_nb_model.fit(X_train, y_train)
y_pred=gategorical_nb_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# Confusion matrix
print("Confusion Matrix")
matrix = confusion_matrix(y_test, y_pred)
print(matrix)
# Classification Report
print("\nClassification Report")
report = classification_report(y_test, y_pred)
print(report)
# Accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print('CategoricalNB Classification Accuracy of the model: {:.2f}%'.format(accuracy*100))
# Out:
# Confusion Matrix
# [[59  8]
#  [11  6]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86        67
#            1       0.43      0.35      0.39        17
#
#     accuracy                           0.77        84
#    macro avg       0.64      0.62      0.62        84
# weighted avg       0.76      0.77      0.77        84
#
# CategoricalNB Classification Accuracy of the model: 77.38%
