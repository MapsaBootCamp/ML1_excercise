# %%
import pandas as pd 
import numpy as np
from sklearn.utils import shuffle
import  matplotlib.pyplot as plt
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.keys()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# x=dt_iris.iloc[:,:-1]
y=iris["species"]

# %%
b=s.drop(labels="species",axis=1)
b
# Out:
#      sepal_length  sepal_width  petal_length  petal_width   ID     ratio
# 0             5.1          3.5           1.4          0.2    0  1.457143
# 1             4.9          3.0           1.4          0.2    1  1.633333
# 2             4.7          3.2           1.3          0.2    2  1.468750
# 3             4.6          3.1           1.5          0.2    3  1.483871
# 4             5.0          3.6           1.4          0.2    4  1.388889
# ..            ...          ...           ...          ...  ...       ...
# 145           6.7          3.0           5.2          2.3  145  2.233333
# 146           6.3          2.5           5.0          1.9  146  2.520000
# 147           6.5          3.0           5.2          2.0  147  2.166667
# 148           6.2          3.4           5.4          2.3  148  1.823529
# 149           5.9          3.0           5.1          1.8  149  1.966667
#
# [150 rows x 6 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(b, y,test_size=0.3,random_state=50)

# %%
knn_clf = KNeighborsClassifier(n_neighbors=1)

# %%
knn_clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
y_predict=knn_clf.predict(X_test)

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       1.00      1.00      1.00        17
#    virginica       1.00      1.00      1.00        14
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[15,  0,  0],
#        [ 0, 17,  0],
#        [ 0,  0, 13]], dtype=int64)

# %%
yy=pd.DataFrame(y_test)
yy
xx=pd.DataFrame(y_train)

# %%
dt=X_test.join(yy)
dt
dtt=X_train.join(xx)

# %%
yy
# Out:
#         species
# 30       setosa
# 0        setosa
# 138   virginica
# 67   versicolor
# 105   virginica
# 39       setosa
# 113   virginica
# 71   versicolor
# 81   versicolor
# 57   versicolor
# 38       setosa
# 76   versicolor
# 122   virginica
# 11       setosa
# 78   versicolor
# 97   versicolor
# 15       setosa
# 12       setosa
# 114   virginica
# 100   virginica
# 37       setosa
# 45       setosa
# 1        setosa
# 134   virginica
# 126   virginica
# 118   virginica
# 17       setosa
# 88   versicolor
# 2        setosa
# 10       setosa
# 96   versicolor
# 19       setosa
# 93   versicolor
# 98   versicolor
# 108   virginica
# 103   virginica
# 50   versicolor
# 120   virginica
# 62   versicolor
# 66   versicolor
# 69   versicolor
# 142   virginica
# 80   versicolor
# 77   versicolor
# 22       setosa

# %%
# plt.scatter(X_test,yy)

iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_s["ratio"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ratio'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-abda54bf7640> in <module>
# ----> 1 iris_s["ratio"]
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
iris_s = sns.load_dataset("iris")
iris["ID"] = iris.index
iris["ratio"] = iris["sepal_length"]/iris["sepal_width"]

sns.lmplot(x="ID", y="ratio", data=iris, hue="species", fit_reg=False, legend=False)
# sns.lmplot(x="ID", y="ratio", data=dt, hue="species", fit_reg=False, legend=False)
plt.legend()
plt.show()

# %%
y_test.unique()
# Out:
# array(['versicolor', 'setosa', 'virginica'], dtype=object)

# %%
# sns.scatterplot(x=X_train.ID, y=X_train.ratio, hue=y_train)
# sns.scatterplot(x=X_test.ID, y=X_test.ratio, hue=y_test, style=y_predict)

# %%
s=iris

# %%
iris = sns.load_dataset("iris")
iris["ID"] = iris.index
iris["ratio"] = iris["sepal_length"]/iris["sepal_width"]

sns.lmplot(x="ID", y="ratio", data=dt, hue="species", fit_reg=False, legend=False)

plt.legend()
plt.show()

# %%
iris = sns.load_dataset("iris")
iris["ID"] = iris.index
iris["ratio"] = iris["sepal_length"]/iris["sepal_width"]

sns.lmplot(x="ID", y="ratio", data=dtt, hue="species", fit_reg=False, legend=False)

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e1de29cc6fac> in <module>
#       3 iris["ratio"] = iris["sepal_length"]/iris["sepal_width"]
#       4
# ----> 5 sns.lmplot(x="ID", y="ratio", data=dtt, hue="species", fit_reg=False, legend=False)
#       6
#       7 plt.legend()
#
# NameError: name 'dtt' is not defined

# %%
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

# %%
iris = datasets.load_iris()

# %%
X = iris.data[:, :2]
y = iris.target

# %%
h = .02
n_neighbors=4
iris.target_names[y]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6fc02a13d4e> in <module>
#       1 h = .02
#       2 n_neighbors=4
# ----> 3 iris.target_names[y]
#
# NameError: name 'iris' is not defined

# %%
cmap_light = ListedColormap(['orange', 'cyan', 'cornflowerblue'])
cmap_bold = ['darkorange', 'c', 'darkblue']

# %%
for weights in ['uniform', 'distance']:
    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure(figsize=(8, 6))
    plt.contourf(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=iris.target_names[y],
                    palette=cmap_bold, alpha=1.0, edgecolor="black")
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("3-Class classification (k = %i, weights = '%s')"
              % (n_neighbors, weights))
    plt.xlabel(iris.feature_names[2])
    plt.ylabel(iris.feature_names[3])

plt.show()
