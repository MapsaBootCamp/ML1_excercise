# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import requests

# %%
r = requests.get('https://api.varzesh3.com/v2.0/news/tag/1028/1775955/1')

# %%
r
# Out:
# <Response [200]>

# %%
txt = r.json()

# %%
len(txt)
# Out:
# 1

# %%
txt[0]
# Out:
# {'Id': 1775932,
#  'NewsType': 2,
#  'Slug': None,
#  'PageTitle': None,
#  'Title': 'نام برنده جایزه مرد سال یوفا لو رفت',
#  'LongTitle': None,
#  'SubTitle': 'ستاره ایتالیایی بهترین بازیکن سال شد؛',
#  'Lead': 'به نظر می رسد جورجینیو، هافبک ایتالیایی چلسی برنده جایزه بهترین بازیکن سال یوفا شده باشد.\r\n\r\n',
#  'Text': '<p dir="RTL" style="text-align: justify;">به گزارش "ورزش سه"، چند روز قبل یوفا اعلام کرد یکی از بین کوین دی بروین، جورجینیو و انگولو کانته به عنوان بهترین بازیکن سال یوفا اعلام خواهد شد و این سه بازیکن در نظرسنجی اولیه بین خبرنگاران و مربیان حاضر لیگ قهرمانان سه رتبه نخست را از آن خود کرده اند. 50 مربی مرحله گروهی لیگ اروپا و لیگ قهرمانان اروپا در فصل گذشته به اضافه 55 خبرنگار در این نظرسنجی شرکت داشته و در نهایت نام این سه بازیکن را اعلام کرده اند. لیونل مسی و رابرت لواندوفسکی نیز در این نطرسنجی رتبه های چهارم و پنجم را به خود اختصاص دادند.</p>\r\n\r\n<p dir="RTL" style="text-align: justify;">&nbsp;</p>\r\n\r\n<p dir="RTL" style="text-align: center;"><img src="https://static2.farakav.com/files/pictures/01627749.jpg" style="max-width:500px" /></p>\r\n\r\n<p dir="RTL" style="text-align: justify;">&nbsp;</p>\r\n\r\n<p dir="RTL" style="text-align: justify;">حالا نشریه ایتالیایی توتو مرکاتووب مدعی شد منابع نزدیک به یوفا به آنها اعلام کرده اند اند که جورجینیو بالاتر از بازیکنانی چون انگولو کانته و کوین دی بروین برنده جایزه بهترین بازیکن سال یوفا شده و نام این هافبک ایتالیایی در جریان قرعه کشی پنجشنبه لیگ قهرمانان در استانبول به عنوان برنده این جایزه اعلام خواهد شد.</p>\r\n\r\n<p dir="RTL" style="text-align: justify;">&nbsp;</p>\r\n\r\n<p dir="RTL" style="text-align: justify;">جورجینیوی 29 ساله فصل گذشته نقش مهمی در کسب عنوان قهرمانی در لیگ قهرمانان با لباس چلسی ایفا کرد. اما درخشش جورجینیو در رقابت های یورو 2020 و در ترکیب تیم ملی ایتالیا نیز ادامه داشت و او با آتزوری نیز فاتح این تورنمنت شد تا حالا بخت اول برای کسب جایزه بهترین بازیکن فصل از سوی یوفا لقب بگیرد. این در حالیست که در ماه سپتامبر جایزه توپ طلای نشریه فرانس فوتبال اهدا خواهد شد و به نظر می رسد آنجا لیونل مسی از بالاترین شانس برای دریافت این جایزه برای هفتمین بار برخوردار باشد.</p>\r\n',
#  'PlainText': 'به گزارش "ورزش سه"، چند روز قبل یوفا اعلام کرد یکی از بین کوین دی بروین، جورجینیو و انگولو کانته به عنوان بهترین بازیکن سال یوفا اعلام خواهد شد و این سه بازیکن در نظرسنجی اولیه بین خبرنگاران و مربیان حاضر لیگ قهرمانان سه رتبه نخست را از آن خود کرده اند. 50 مربی مرحله گروهی لیگ اروپا و لیگ قهرمانان اروپا در فصل گذشته به اضافه 55 خبرنگار در این نظرسنجی شرکت داشته و در نهایت نام این سه بازیکن را اعلام کرده اند. لیونل مسی و رابرت لواندوفسکی نیز در این نطرسنجی رتبه های چهارم و پنجم را به خود اختصاص دادند.\r\n\r\n&nbsp;\r\n\r\n\r\n\r\n&nbsp;\r\n\r\nحالا نشریه ایتالیایی توتو مرکاتووب مدعی شد منابع نزدیک به یوفا به آنها اعلام کرده اند اند که جورجینیو بالاتر از بازیکنانی چون انگولو کانته و کوین دی بروین برنده جایزه بهترین بازیکن سال یوفا شده و نام این هافبک ایتالیایی در جریان قرعه کشی پنجشنبه لیگ قهرمانان در استانبول به عنوان برنده این جایزه اعلام خواهد شد.\r\n\r\n&nbsp;\r\n\r\nجورجینیوی 29 ساله فصل گذشته نقش مهمی در کسب عنوان قهرمانی در لیگ قهرمانان با لباس چلسی ایفا کرد. اما درخشش جورجینیو در رقابت های یورو 2020 و در ترکیب تیم ملی ایتالیا نیز ادامه داشت و او با آتزوری نیز فاتح این تورنمنت شد تا حالا بخت اول برای کسب جایزه بهترین بازیکن فصل از سوی یوفا لقب بگیرد. این در حالیست که در ماه سپتامبر جایزه توپ طلای نشریه فرانس فوتبال اهدا خواهد شد و به نظر می رسد آنجا لیونل مسی از بالاترین شانس برای دریافت این جایزه برای هفتمین بار برخوردار باشد.\r\n',
#  'Featured': False,
#  'Picture': '01623056.jpg',
#  'Path': 'https://static.farakav.com/files/pictures/thumb/01623056.jpg',
#  'Url': 'https://www.varzesh3.com/news/1775932/نام-برنده-جایزه-مرد-سال-یوفا-لو-رفت',
#  'FullSizeImage': 'https://static.farakav.com/files/pictures/01623056.jpg',
#  'ShareURL': 'http://n.varzesh3.com/n/PBkb',
#  'Reference': None,
#  'ViewCount': 47236,
#  'CreationDate': '2021-08-25T19:49:38',
#  'Date': '1400/06/03',
#  'Time': '19:48',
#  'VideoURL': None,
#  'LastUpdate': '2021-08-25T19:48:00',
#  'RelativeDate': 'دیروز',
#  'ReadableDate': 'چهارشنبه 3 شهریور 1400'}

# %%
aaa = pd.DataFrame({txt[0]['Id']:[txt[0]['Title'],txt[0]['Lead'],txt[0]['ViewCount'],txt[0]['Date'],txt[0]['PlainText']]})

# %%
aaa
# Out:
#                                              1775932
# 0                نام برنده جایزه مرد سال یوفا لو رفت
# 1  به نظر می رسد جورجینیو، هافبک ایتالیایی چلسی ب...
# 2                                              47236
# 3                                         1400/06/03
# 4  به گزارش "ورزش سه"، چند روز قبل یوفا اعلام کرد...

# %%
aaa.index = ['عنوان خبر','سر خط خبر','تعداد بازدید','تاریخ','متن خبر']

# %%
aaa
# Out:
#                                                         1775932
# عنوان خبر                   نام برنده جایزه مرد سال یوفا لو رفت
# سر خط خبر     به نظر می رسد جورجینیو، هافبک ایتالیایی چلسی ب...
# تعداد بازدید                                              47236
# تاریخ                                                1400/06/03
# متن خبر       به گزارش "ورزش سه"، چند روز قبل یوفا اعلام کرد...

# %%
txt[0]['Date'].split('/')[0]
# Out:
# '1400'

# %%
while r:
    r = requests.get(f"https://api.varzesh3.com/v2.0/news/tag/1028/{txts[-1]['Id']}/100")
    if r:
        txts = r.json()
        for txt in txts:
            aaa[txt['Id']] = [txt['Title'],txt['Lead'],txt['ViewCount'],txt['Date'],txt['PlainText']]
            if int(txt['Date'].split('/')[0]) < 1397:
                break
# Out:
# C:\Users\AMIREL~1\AppData\Local\Temp/ipykernel_3112/4198361473.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   aaa[txt[0]['Id']] = [txt[0]['Title'],txt[0]['Lead'],txt[0]['ViewCount'],txt[0]['Date'],txt[0]['PlainText']]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\AMIREL~1\AppData\Local\Temp/ipykernel_3112/4198361473.py in <module>
#       1 while r:
# ----> 2     r = requests.get(f"https://api.varzesh3.com/v2.0/news/tag/1028/{txt[0]['Id']}/1")
#       3     if r:
#       4         txt = r.json()
#       5         aaa[txt[0]['Id']] = [txt[0]['Title'],txt[0]['Lead'],txt[0]['ViewCount'],txt[0]['Date'],txt[0]['PlainText']]
#
# c:\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\python\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\python\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\python\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# c:\python\python39\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# c:\python\python39\lib\site-packages\urllib3\connection.py in connect(self)
#     409             context.load_default_certs()
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#     413             keyfile=self.key_file,
#
# c:\python\python39\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400     if ca_certs or ca_cert_dir or ca_cert_data:
#     401         try:
# --> 402             context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403         except (IOError, OSError) as e:
#     404             raise SSLError(e)
#
# KeyboardInterrupt:

# %%
aaa
# Out:
#                                                         1775932  \
# عنوان خبر                   نام برنده جایزه مرد سال یوفا لو رفت
# سر خط خبر     به نظر می رسد جورجینیو، هافبک ایتالیایی چلسی ب...
# تعداد بازدید                                              47236
# تاریخ                                                1400/06/03
# متن خبر       به گزارش "ورزش سه"، چند روز قبل یوفا اعلام کرد...
#
#                                                         1775773  \
# عنوان خبر     بمب در اروپا؛ رونالدو و مسی همبازی می شوند؟ (عکس)
# سر خط خبر     شایعات در مورد جدایی کریستیانو رونالدو از یوون...
# تعداد بازدید                                             197182
# تاریخ                                                1400/06/02
# متن خبر       به گزارش "ورزش سه"، خلیفه بن حمد آل ثانی، براد...
#
#                                                         1775755  \
# عنوان خبر                    کلوپ: دلیلی ندارد به PSG حسادت کنم
# سر خط خبر     یورگن کلوپ، سرمربی آلمان لیورپول تاکید کرد که ...
# تعداد بازدید                                              11022
# تاریخ                                                1400/06/02
# متن خبر       به گزارش "ورزش سه"، باشگاه لیورپول در تابستان ...
#
#                                                         1775712  \
# عنوان خبر        تب مسی؛ تقاضای بلیت از سراسر دنیا برای رنس-PSG
# سر خط خبر     مدیر فروش باشگاه رنس از تقاضای بلیت بازی این ت...
# تعداد بازدید                                              35604
# تاریخ                                                1400/06/02
# متن خبر       به گزارش "ورزش سه"، یکشنبه شب هفته بعد احتمالا...
#
#                                                         1775695  \
# عنوان خبر      امباپه: هت‌تریک برابر بارسا بهترین بازی عمرم بود
# سر خط خبر     کیلیان امباپه بازی برابر بارسا در نوکمپ را هرگ...
# تعداد بازدید                                              18127
# تاریخ                                                1400/06/02
# متن خبر       به گزارش "ورزش سه"، کیلیان امباپه این روزها به...
#
#                                                         1775604  \
# عنوان خبر                    کابوس دو ساله دیبالا تمام شد (عکس)
# سر خط خبر     پائولو دیبالا بعد از دو سال دوری دوباره فرصت ب...
# تعداد بازدید                                              60567
# تاریخ                                                1400/06/01
# متن خبر       به گزارش "ورزش سه"، لیست بازیکنان تیم ملی آرژا...
#
#                                                         1775589  \
# عنوان خبر             مایکل جردن هنوز از انتقال مسی سود می گیرد
# سر خط خبر     انتقال لیونل مسی سود قابل توجهی برای مایکل جرد...
# تعداد بازدید                                              35326
# تاریخ                                                1400/06/01
# متن خبر       به گزارش "ورزش سه"، مایکل جردن این روزها دلایل...
#
#                                                         1775582  \
# عنوان خبر                       زمان رونمایی از لئو مسی مشخص شد
# سر خط خبر     به نظر می رسد کمتر از یک هفته دیگر موعد رونمای...
# تعداد بازدید                                              39321
# تاریخ                                                1400/06/01
# متن خبر       به گزارش "ورزش سه"، چند هفته ای از انتقال غیرم...
#
#                                                         1775466  \
# عنوان خبر           اخطار رییس بایرن به PSG و یوفا؛ حواسمان هست
# سر خط خبر     هربرت هاینر، رییس بایرن مونیخ، با انتقاد از PS...
# تعداد بازدید                                              25422
# تاریخ                                                1400/06/01
# متن خبر       به گزارش "ورزش سه"، هربرت هاینر اخیرا در مصاحب...
#
#                                                         1775376  ...  \
# عنوان خبر            واکنش جالب کلوپ به انتقال لئو مسی به پاریس  ...
# سر خط خبر     یورگن کلوپ، سرمربی آلمانی لیورپول مدعی شد بارس...  ...
# تعداد بازدید                                              48121  ...
# تاریخ                                                1400/05/31  ...
# متن خبر       به گزارش "ورزش سه"، اگرچه به نظر می رسید با ور...  ...
#
#                                                         1728808  \
# عنوان خبر                رونالدو؛ سلطان لایک اینستاگرام در 2020
# سر خط خبر     بیشترین میزان لایک شدن یک پست اینستاگرامی در س...
# تعداد بازدید                                              72203
# تاریخ                                                1399/10/12
# متن خبر       به گزارش "ورزش سه"، در پایان سال 2020 میلادی م...
#
#                                                         1728489  \
# عنوان خبر      حاضر نبودم برای سیمئونه بازی کنم؛ برای زیدان چرا
# سر خط خبر     ستاره سابق منچستریونایتد دوست داشت بازی زیر نظ...
# تعداد بازدید                                              10391
# تاریخ                                                1399/10/10
# متن خبر       به گزارش "ورزش سه"، دیمیتار برباتوف ستاره بلغا...
#
#                                                         1728472  \
# عنوان خبر               تمدید با بارسا؛ برنامه نهایی مسی فاش شد
# سر خط خبر     لیونل مسی تصمیمش برای تمدید با بارسا را گرفته ...
# تعداد بازدید                                             113169
# تاریخ                                                1399/10/10
# متن خبر       به گزارش "ورزش سه"، به نقل از موندودپورتیوو، ل...
#
#                                                         1728466  \
# عنوان خبر     سوارز: کسی غیر از برایثویت نبود پنالتی بارسا ر...
# سر خط خبر     لوئیس سوارز میرامونته بازیکن سابق بارسا و تنها...
# تعداد بازدید                                              32130
# تاریخ                                                1399/10/10
# متن خبر       به گزارش "ورزش سه"، بارسلونا شب گذشته در نوکمپ...
#
#                                                         1728449  \
# عنوان خبر           نامزد ریاست بارسا: الان وقت خرید نیمار نیست
# سر خط خبر     آگوستی بندیتو نامزد انتخابات بارسلونا می گوید ...
# تعداد بازدید                                               8985
# تاریخ                                                1399/10/10
# متن خبر       به گزارش "ورزش سه"، آگوستی بندیتو نامزد ریاست ...
#
#                                                         1728412  \
# عنوان خبر              تاسف مسی از تساوی بارسا مقابل آیبار(عکس)
# سر خط خبر     چهره ناراحت مسی و سر تکان دادن او بعد از تساوی...
# تعداد بازدید                                              29044
# تاریخ                                                1399/10/10
# متن خبر       به گزارش "ورزش سه"، بارسلونا دیشب در نوکمپ در ...
#
#                                                         1728374  \
# عنوان خبر            کومان: دیگر شانس زیادی برای قهرمانی نداریم
# سر خط خبر     رونالد کومان تساوی امشب بارسا برابر ایبار را غ...
# تعداد بازدید                                              35436
# تاریخ                                                1399/10/10
# متن خبر       به گزارش "ورزش سه"؛ سال وحشتناک و اسف بار 2020...
#
#                                                         1728246  \
# عنوان خبر           بارسا بدون مسی برابر ایبار؛ غیبت تاثیرگذار؟
# سر خط خبر     لیونل مسی این فصل در دو بازی بارسا غیبت داشته ...
# تعداد بازدید                                               9908
# تاریخ                                                1399/10/09
# متن خبر       به گزارش "ورزش سه"، لیونل مسی فصل جاری در 18 ب...
#
#                                                         1728221  \
# عنوان خبر               لاپورتا: ماندگاری مسی در بارسا ممکن است
# سر خط خبر     خوان لاپورتا نامزد ریاست بارسلونا می گوید شرای...
# تعداد بازدید                                               8951
# تاریخ                                                1399/10/09
# متن خبر       به گزارش "ورزش سه"، خوان لاپورتا نامزد ریاست ب...
#
#                                                         1728183
# عنوان خبر       رادیو کاتالونیا: مسی و سوارز در تیم دیوید بکهام
# سر خط خبر     رادیو کاتالونیا مدعی شد لیونل مسی و لوئیس سوار...
# تعداد بازدید                                              16288
# تاریخ                                                1399/10/09
# متن خبر       به گزارش "ورزش سه"، ژاوی&nbsp;کامپوس روزنامه‌ن...
#
# [5 rows x 906 columns]

# %%
aaa.to_csv('messi_varzesh3_test.csv')

# %%
dfs = pd.read_csv('messi_varzesh3_test.csv')

# %%
dfs
# Out:
#      Unnamed: 0                                            1775932  \
# 0     عنوان خبر                نام برنده جایزه مرد سال یوفا لو رفت
# 1     سر خط خبر  به نظر می رسد جورجینیو، هافبک ایتالیایی چلسی ب...
# 2  تعداد بازدید                                              47236
# 3         تاریخ                                         1400/06/03
# 4       متن خبر  به گزارش "ورزش سه"، چند روز قبل یوفا اعلام کرد...
#
#                                              1775773  \
# 0  بمب در اروپا؛ رونالدو و مسی همبازی می شوند؟ (عکس)
# 1  شایعات در مورد جدایی کریستیانو رونالدو از یوون...
# 2                                             197182
# 3                                         1400/06/02
# 4  به گزارش "ورزش سه"، خلیفه بن حمد آل ثانی، براد...
#
#                                              1775755  \
# 0                 کلوپ: دلیلی ندارد به PSG حسادت کنم
# 1  یورگن کلوپ، سرمربی آلمان لیورپول تاکید کرد که ...
# 2                                              11022
# 3                                         1400/06/02
# 4  به گزارش "ورزش سه"، باشگاه لیورپول در تابستان ...
#
#                                              1775712  \
# 0     تب مسی؛ تقاضای بلیت از سراسر دنیا برای رنس-PSG
# 1  مدیر فروش باشگاه رنس از تقاضای بلیت بازی این ت...
# 2                                              35604
# 3                                         1400/06/02
# 4  به گزارش "ورزش سه"، یکشنبه شب هفته بعد احتمالا...
#
#                                              1775695  \
# 0   امباپه: هت‌تریک برابر بارسا بهترین بازی عمرم بود
# 1  کیلیان امباپه بازی برابر بارسا در نوکمپ را هرگ...
# 2                                              18127
# 3                                         1400/06/02
# 4  به گزارش "ورزش سه"، کیلیان امباپه این روزها به...
#
#                                              1775604  \
# 0                 کابوس دو ساله دیبالا تمام شد (عکس)
# 1  پائولو دیبالا بعد از دو سال دوری دوباره فرصت ب...
# 2                                              60567
# 3                                         1400/06/01
# 4  به گزارش "ورزش سه"، لیست بازیکنان تیم ملی آرژا...
#
#                                              1775589  \
# 0          مایکل جردن هنوز از انتقال مسی سود می گیرد
# 1  انتقال لیونل مسی سود قابل توجهی برای مایکل جرد...
# 2                                              35326
# 3                                         1400/06/01
# 4  به گزارش "ورزش سه"، مایکل جردن این روزها دلایل...
#
#                                              1775582  \
# 0                    زمان رونمایی از لئو مسی مشخص شد
# 1  به نظر می رسد کمتر از یک هفته دیگر موعد رونمای...
# 2                                              39321
# 3                                         1400/06/01
# 4  به گزارش "ورزش سه"، چند هفته ای از انتقال غیرم...
#
#                                              1775466  ...  \
# 0        اخطار رییس بایرن به PSG و یوفا؛ حواسمان هست  ...
# 1  هربرت هاینر، رییس بایرن مونیخ، با انتقاد از PS...  ...
# 2                                              25422  ...
# 3                                         1400/06/01  ...
# 4  به گزارش "ورزش سه"، هربرت هاینر اخیرا در مصاحب...  ...
#
#                                              1728808  \
# 0             رونالدو؛ سلطان لایک اینستاگرام در 2020
# 1  بیشترین میزان لایک شدن یک پست اینستاگرامی در س...
# 2                                              72203
# 3                                         1399/10/12
# 4  به گزارش "ورزش سه"، در پایان سال 2020 میلادی م...
#
#                                              1728489  \
# 0   حاضر نبودم برای سیمئونه بازی کنم؛ برای زیدان چرا
# 1  ستاره سابق منچستریونایتد دوست داشت بازی زیر نظ...
# 2                                              10391
# 3                                         1399/10/10
# 4  به گزارش "ورزش سه"، دیمیتار برباتوف ستاره بلغا...
#
#                                              1728472  \
# 0            تمدید با بارسا؛ برنامه نهایی مسی فاش شد
# 1  لیونل مسی تصمیمش برای تمدید با بارسا را گرفته ...
# 2                                             113169
# 3                                         1399/10/10
# 4  به گزارش "ورزش سه"، به نقل از موندودپورتیوو، ل...
#
#                                              1728466  \
# 0  سوارز: کسی غیر از برایثویت نبود پنالتی بارسا ر...
# 1  لوئیس سوارز میرامونته بازیکن سابق بارسا و تنها...
# 2                                              32130
# 3                                         1399/10/10
# 4  به گزارش "ورزش سه"، بارسلونا شب گذشته در نوکمپ...
#
#                                              1728449  \
# 0        نامزد ریاست بارسا: الان وقت خرید نیمار نیست
# 1  آگوستی بندیتو نامزد انتخابات بارسلونا می گوید ...
# 2                                               8985
# 3                                         1399/10/10
# 4  به گزارش "ورزش سه"، آگوستی بندیتو نامزد ریاست ...
#
#                                              1728412  \
# 0           تاسف مسی از تساوی بارسا مقابل آیبار(عکس)
# 1  چهره ناراحت مسی و سر تکان دادن او بعد از تساوی...
# 2                                              29044
# 3                                         1399/10/10
# 4  به گزارش "ورزش سه"، بارسلونا دیشب در نوکمپ در ...
#
#                                              1728374  \
# 0         کومان: دیگر شانس زیادی برای قهرمانی نداریم
# 1  رونالد کومان تساوی امشب بارسا برابر ایبار را غ...
# 2                                              35436
# 3                                         1399/10/10
# 4  به گزارش "ورزش سه"؛ سال وحشتناک و اسف بار 2020...
#
#                                              1728246  \
# 0        بارسا بدون مسی برابر ایبار؛ غیبت تاثیرگذار؟
# 1  لیونل مسی این فصل در دو بازی بارسا غیبت داشته ...
# 2                                               9908
# 3                                         1399/10/09
# 4  به گزارش "ورزش سه"، لیونل مسی فصل جاری در 18 ب...
#
#                                              1728221  \
# 0            لاپورتا: ماندگاری مسی در بارسا ممکن است
# 1  خوان لاپورتا نامزد ریاست بارسلونا می گوید شرای...
# 2                                               8951
# 3                                         1399/10/09
# 4  به گزارش "ورزش سه"، خوان لاپورتا نامزد ریاست ب...
#
#                                              1728183
# 0    رادیو کاتالونیا: مسی و سوارز در تیم دیوید بکهام
# 1  رادیو کاتالونیا مدعی شد لیونل مسی و لوئیس سوار...
# 2                                              16288
# 3                                         1399/10/09
# 4  به گزارش "ورزش سه"، ژاوی&nbsp;کامپوس روزنامه‌ن...
#
# [5 rows x 907 columns]

# %%
#import requests
#import csv


#r = requests.get('https://api.varzesh3.com/v2.0/news/tag/1028/1775955/1')
#if r:
#    txts = txt = r.json()
#    with open('messi_varzesh3.csv', 'w', newline='', encoding='utf-8') as csvfile:
#        fieldnames = ['Id','Title','Lead','ViewCount','Date','PlainText']
#        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#        writer.writeheader()
#        data_dict = {'Id':txt[0]['Id'],'Title':txt[0]['Title'],'Lead':txt[0]['Lead'],'ViewCount':txt[0]['ViewCount']
#                        ,'Date':txt[0]['Date'],'PlainText':txt[0]['PlainText']}
#        writer.writerow(data_dict)
#        while r:
#            r = requests.get(f"https://api.varzesh3.com/v2.0/news/tag/1028/{txts[-1]['Id']}/100")
#            if r:
#                txts = r.json()
#                for txt in txts:
#                    data_dict = {'Id':txt['Id'],'Title':txt['Title'],'Lead':txt['Lead'],'ViewCount':txt['ViewCount']
#                        ,'Date':txt['Date'],'PlainText':txt['PlainText']}
#                    writer.writerow(data_dict)
#                    if int(txt['Date'].split('/')[0]) < 1397:
#                       break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\AMIREL~1\AppData\Local\Temp/ipykernel_3112/3787703727.py in <module>
#      14         writer.writerow(data_dict)
#      15         while r:
# ---> 16             r = requests.get(f"https://api.varzesh3.com/v2.0/news/tag/1028/{txts[-1]['Id']}/100")
#      17             if r:
#      18                 txts = r.json()
#
# IndexError: list index out of range

# %%
df = pd.read_csv('messi_varzesh3.csv', index_col='Id')

# %%
df
# Out:
#                                                      Title  \
# Id
# 1775932                نام برنده جایزه مرد سال یوفا لو رفت
# 1775773  بمب در اروپا؛ رونالدو و مسی همبازی می شوند؟ (عکس)
# 1775755                 کلوپ: دلیلی ندارد به PSG حسادت کنم
# 1775712     تب مسی؛ تقاضای بلیت از سراسر دنیا برای رنس-PSG
# 1775695   امباپه: هت‌تریک برابر بارسا بهترین بازی عمرم بود
# ...                                                    ...
# 991934                  طلسم برپای کریس، مسی و فالکائو\r\n
# 974449            مسی: بارسا با نبود گواردیولا کنار می آید
# 63047               مسی: فقط می خواهم فوتبال بازی كنم \r\n
# 47661    مسی: می خواهم با آرژانتین قهرمان جام جهانی شوم...
# 27531          مسی گلزن اول تاریخ بارسا در لیگ‌های اروپایی
#
#                                                       Lead  ViewCount  \
# Id
# 1775932  به نظر می رسد جورجینیو، هافبک ایتالیایی چلسی ب...      47281
# 1775773  شایعات در مورد جدایی کریستیانو رونالدو از یوون...     197233
# 1775755  یورگن کلوپ، سرمربی آلمان لیورپول تاکید کرد که ...      11026
# 1775712  مدیر فروش باشگاه رنس از تقاضای بلیت بازی این ت...      35614
# 1775695  کیلیان امباپه بازی برابر بارسا در نوکمپ را هرگ...      18138
# ...                                                    ...        ...
# 991934     در حال حاضر در جدول گلزنان لالیگا، مسی 13 گل...        555
# 974449   مهاجم آرژانتینی درصحبتهایی اعلام کرد که هیچ وق...        459
# 63047     ستاره بارسلونا ابراز امیدواری کرد که برای سوم...        744
# 47661    لیونل مسی ستاره آرژانتینی بارسلونا معتقد است م...        184
# 27531    مهاجم آرژانتینی تیم فوتبال بارسلونا در صدر جدو...        327
#
#                Date                                          PlainText
# Id
# 1775932  1400/06/03  به گزارش "ورزش سه"، چند روز قبل یوفا اعلام کرد...
# 1775773  1400/06/02  به گزارش "ورزش سه"، خلیفه بن حمد آل ثانی، براد...
# 1775755  1400/06/02  به گزارش "ورزش سه"، باشگاه لیورپول در تابستان ...
# 1775712  1400/06/02  به گزارش "ورزش سه"، یکشنبه شب هفته بعد احتمالا...
# 1775695  1400/06/02  به گزارش "ورزش سه"، کیلیان امباپه این روزها به...
# ...             ...                                                ...
# 991934   1391/08/14  \r\n&nbsp; در روزی که&nbsp; لیونل مسی در گلزنی...
# 974449   1391/03/13  لیونل مسی،ستاره آرژانتینی باشگاه بارسلونا معتق...
# 63047    1390/10/05  &nbsp;&nbsp; &nbsp;ليونل مسي ستاره آرژانتيني ب...
# 47661    1390/04/11  &nbsp; مسی قبل از&nbsp;اولین بازی تیم ملی&nbsp...
# 27531    1389/06/24  \r\n&nbsp;ليونل مسي شب گذشته دو بار دروازه پان...
#
# [4213 rows x 5 columns]

# %%
df['Date'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
df2 = df.groupby('Date').agg({'ViewCount':sum})

# %%
df2.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
